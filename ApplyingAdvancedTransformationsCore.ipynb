# %%
# imports
import pandas as pd
import numpy as np
import os,json

# set the max columns to none
pd.set_option('display.max_columns', None)

import warnings
# Settings the warnings to be ignored 
warnings.filterwarnings('ignore')

# %%
# Loading in data
df1 = pd.read_csv("Data/superhero_info.csv")
df1.head()
# Out:
#                  Hero|Publisher Gender               Race Alignment  \
# 0          A-Bomb|Marvel Comics   Male              Human      good
# 1  Abe Sapien|Dark Horse Comics   Male      Icthyo Sapien      good
# 2            Abin Sur|DC Comics   Male            Ungaran      good
# 3     Abomination|Marvel Comics   Male  Human / Radiation       bad
# 4   Absorbing Man|Marvel Comics   Male              Human       bad
#
#   Hair color Eye color Skin color  \
# 0    No Hair    yellow    Unknown
# 1    No Hair      blue       blue
# 2    No Hair      blue        red
# 3    No Hair     green    Unknown
# 4    No Hair      blue    Unknown
#
#                                    Measurements
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}

# %%
df2 = pd.read_csv("Data/superhero_powers.csv")
df2.head()
# Out:
#     hero_names                                             Powers
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...

# %% [markdown]
# Data clean-up

# %%
# Splitting and dropping Hero|Publisher column
df1[["Hero","Publisher"]] = df1["Hero|Publisher"].str.split("|",expand=True)
df1 = df1.drop(columns = "Hero|Publisher")
df1.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#                                    Measurements           Hero  \
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}         A-Bomb
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}     Abe Sapien
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}       Abin Sur
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}    Abomination
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}  Absorbing Man
#
#            Publisher
# 0      Marvel Comics
# 1  Dark Horse Comics
# 2          DC Comics
# 3      Marvel Comics
# 4      Marvel Comics

# %%
df1[["Height(cm)","Weight(kg)"]] = df1["Measurements"].str.split(",",expand=True)
df1 = df1.drop(columns = "Measurements")
df1.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher             Height(cm)  \
# 0         A-Bomb      Marvel Comics  {'Height': '203.0 cm'
# 1     Abe Sapien  Dark Horse Comics  {'Height': '191.0 cm'
# 2       Abin Sur          DC Comics  {'Height': '185.0 cm'
# 3    Abomination      Marvel Comics  {'Height': '203.0 cm'
# 4  Absorbing Man      Marvel Comics  {'Height': '193.0 cm'
#
#                Weight(kg)
# 0   'Weight': '441.0 kg'}
# 1    'Weight': '65.0 kg'}
# 2    'Weight': '90.0 kg'}
# 3   'Weight': '441.0 kg'}
# 4   'Weight': '122.0 kg'}

# %%
# Make a list of all characters to replace
to_replace = ['{','Height','Weight',"'",':','}',' ','kg','cm']
# run a loop to replace all of the characters in the list at once
for char in to_replace:
    df1['Height(cm)'] = df1['Height(cm)'].str.replace(char,'',regex=False)
    df1['Weight(kg)'] = df1['Weight(kg)'].str.replace(char,'',regex=False)

# %%
df1.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher Height(cm) Weight(kg)
# 0         A-Bomb      Marvel Comics      203.0      441.0
# 1     Abe Sapien  Dark Horse Comics      191.0       65.0
# 2       Abin Sur          DC Comics      185.0       90.0
# 3    Abomination      Marvel Comics      203.0      441.0
# 4  Absorbing Man      Marvel Comics      193.0      122.0

# %%
## merging with different column names
dfmerged = pd.merge(df1, df2, left_on='Hero', right_on='hero_names')
dfmerged
# Out:
#      Gender               Race Alignment        Hair color Eye color  \
# 0      Male              Human      good           No Hair    yellow
# 1      Male      Icthyo Sapien      good           No Hair      blue
# 2      Male            Ungaran      good           No Hair      blue
# 3      Male  Human / Radiation       bad           No Hair     green
# 4      Male              Human       bad           No Hair      blue
# ..      ...                ...       ...               ...       ...
# 458    Male              Human      good             Blond      blue
# 459  Female              Human      good  Strawberry Blond      blue
# 460    Male     Yoda's species      good             White     brown
# 461  Female              Human      good             Black      blue
# 462    Male            Unknown       bad             Brown       red
#
#     Skin color             Hero          Publisher Height(cm) Weight(kg)  \
# 0      Unknown           A-Bomb      Marvel Comics      203.0      441.0
# 1         blue       Abe Sapien  Dark Horse Comics      191.0       65.0
# 2          red         Abin Sur          DC Comics      185.0       90.0
# 3      Unknown      Abomination      Marvel Comics      203.0      441.0
# 4      Unknown    Absorbing Man      Marvel Comics      193.0      122.0
# ..         ...              ...                ...        ...        ...
# 458    Unknown     Yellowjacket      Marvel Comics      183.0       83.0
# 459    Unknown  Yellowjacket II      Marvel Comics      165.0       52.0
# 460      green             Yoda       George Lucas       66.0       17.0
# 461    Unknown          Zatanna          DC Comics      170.0       57.0
# 462    Unknown             Zoom          DC Comics      185.0       81.0
#
#           hero_names                                             Powers
# 0             A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 1         Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 2           Abin Sur                                 Lantern Power Ring
# 3        Abomination  Accelerated Healing,Intelligence,Super Strengt...
# 4      Absorbing Man  Cold Resistance,Durability,Energy Absorption,S...
# ..               ...                                                ...
# 458     Yellowjacket               Size Changing,Animal Oriented Powers
# 459  Yellowjacket II                 Flight,Energy Blasts,Size Changing
# 460             Yoda  Agility,Stealth,Danger Sense,Marksmanship,Weap...
# 461          Zatanna  Cryokinesis,Telepathy,Magic,Fire Control,Proba...
# 462             Zoom  Super Speed,Intangibility,Time Travel,Time Man...
#
# [463 rows x 12 columns]

# %%
# dropping unwanted hero_names column
dfmerged = dfmerged.drop(columns = "hero_names")
dfmerged.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher Height(cm) Weight(kg)  \
# 0         A-Bomb      Marvel Comics      203.0      441.0
# 1     Abe Sapien  Dark Horse Comics      191.0       65.0
# 2       Abin Sur          DC Comics      185.0       90.0
# 3    Abomination      Marvel Comics      203.0      441.0
# 4  Absorbing Man      Marvel Comics      193.0      122.0
#
#                                               Powers
# 0  Accelerated Healing,Durability,Longevity,Super...
# 1  Agility,Accelerated Healing,Cold Resistance,Du...
# 2                                 Lantern Power Ring
# 3  Accelerated Healing,Intelligence,Super Strengt...
# 4  Cold Resistance,Durability,Energy Absorption,S...

# %%
dfmerged["Powers_split"] = dfmerged["Powers"].str.split(",")
dfmerged["Powers_split"]
# Out:
# 0      [Accelerated Healing, Durability, Longevity, S...
# 1      [Agility, Accelerated Healing, Cold Resistance...
# 2                                   [Lantern Power Ring]
# 3      [Accelerated Healing, Intelligence, Super Stre...
# 4      [Cold Resistance, Durability, Energy Absorptio...
#                              ...
# 458              [Size Changing, Animal Oriented Powers]
# 459               [Flight, Energy Blasts, Size Changing]
# 460    [Agility, Stealth, Danger Sense, Marksmanship,...
# 461    [Cryokinesis, Telepathy, Magic, Fire Control, ...
# 462    [Super Speed, Intangibility, Time Travel, Time...
# Name: Powers_split, Length: 463, dtype: object

# %%
exploded = dfmerged.explode("Powers_split")
exploded[["Hero","Powers","Powers_split"]].head()
# Out:
#      Hero                                             Powers  \
# 0  A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 0  A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 0  A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 0  A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 0  A-Bomb  Accelerated Healing,Durability,Longevity,Super...
#
#           Powers_split
# 0  Accelerated Healing
# 0           Durability
# 0            Longevity
# 0       Super Strength
# 0              Stamina

# %%
cols_to_make = exploded["Powers_split"].dropna().unique()
cols_to_make
# Out:
# array(['Accelerated Healing', 'Durability', 'Longevity', 'Super Strength',
#        'Stamina', 'Camouflage', 'Self-Sustenance', 'Agility',
#        'Cold Resistance', 'Underwater breathing', 'Marksmanship',
#        'Weapons Master', 'Intelligence', 'Telepathy', 'Immortality',
#        'Reflexes', 'Enhanced Sight', 'Sub-Mariner', 'Lantern Power Ring',
#        'Super Speed', 'Invulnerability', 'Animation', 'Super Breath',
#        'Energy Absorption', 'Elemental Transmogrification',
#        'Fire Resistance', 'Natural Armor', 'Molecular Manipulation',
#        'Heat Resistance', 'Matter Absorption', 'Stealth', 'Flight',
#        'Power Suit', 'Energy Blasts', 'Energy Beams', 'Power Cosmic',
#        'Heat Generation', 'Danger Sense', 'Teleportation', 'Phasing',
#        'Force Fields', 'Hypnokinesis', 'Energy Manipulation',
#        'Invisibility', 'Enhanced Senses', 'Jump', 'Substance Secretion',
#        'Natural Weapons', 'Wallcrawling', 'Vision - Thermal',
#        'Power Augmentation', 'Cryokinesis', 'Duplication',
#        'Size Changing', 'Weapon-based Powers', 'Shapeshifting',
#        'Fire Control', 'Enhanced Memory', 'Energy Constructs',
#        'Power Absorption', 'Enhanced Hearing', 'Time Travel',
#        'Enhanced Smell', 'Water Control', 'Vision - Telescopic',
#        'Magnetism', 'Vision - Microscopic', 'Vision - Night',
#        'Vision - Heat', 'Vision - X-Ray', 'Magic', 'Psionic Powers',
#        'Gliding', 'Toxin and Disease Resistance', 'Animal Attributes',
#        'Animal Oriented Powers', 'Regeneration',
#        'Toxin and Disease Control', 'Empathy', 'Animal Control',
#        'Elasticity', 'Web Creation', 'Symbiote Costume', 'Telekinesis',
#        'Levitation', 'Biokinesis', 'Sonar', 'Enhanced Touch',
#        'Seismic Power', 'Energy Armor', 'Radiation Immunity',
#        'Density Control', 'Light Control', 'Illumination',
#        'Molecular Combustion', 'Dimensional Travel', 'Audio Control',
#        'Sonic Scream', 'Peak Human Condition', 'Vision - Infrared',
#        'Dexterity', 'Energy Resistance', 'Vision - Cryo', 'Clairvoyance',
#        'Probability Manipulation', 'Electrokinesis',
#        'Darkforce Manipulation', 'Illusions', 'Death Touch',
#        'Gravity Control', 'Precognition', 'Time Manipulation',
#        'Omnilingualism', 'Astral Projection', 'Technopath/Cyberpath',
#        'Mind Control', 'Mind Blast', 'Cloaking', 'Telepathy Resistance',
#        'Mind Control Resistance', 'Radiation Control',
#        'Radiation Absorption', 'Magic Resistance',
#        'Dimensional Awareness', 'Intangibility', 'Element Control',
#        'Wind Control', 'Echolocation', 'Radar Sense', 'Resurrection',
#        'The Force', 'Possession', 'Astral Travel', 'Summoning', 'Banish',
#        'Adaptation', 'Electrical Transport', 'Speed Force', 'Omnipotent',
#        'Grim Reaping', 'Reality Warping', 'Portal Creation',
#        'Vitakinesis', 'Projection', 'Insanity', 'Plant Control',
#        'Photographic Reflexes', 'Anti-Gravity', 'Power Nullifier',
#        'Hair Manipulation', 'Weather Control', 'Nova Force', 'Odin Force',
#        'Phoenix Force', 'Power Sense', 'Qwardian Power Ring', 'Melting',
#        'Changing Armor', 'Terrakinesis'], dtype=object)

# %%
for col in cols_to_make:
    dfmerged[col] = dfmerged["Powers"].str.contains(col)
dfmerged.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher Height(cm) Weight(kg)  \
# 0         A-Bomb      Marvel Comics      203.0      441.0
# 1     Abe Sapien  Dark Horse Comics      191.0       65.0
# 2       Abin Sur          DC Comics      185.0       90.0
# 3    Abomination      Marvel Comics      203.0      441.0
# 4  Absorbing Man      Marvel Comics      193.0      122.0
#
#                                               Powers  \
# 0  Accelerated Healing,Durability,Longevity,Super...
# 1  Agility,Accelerated Healing,Cold Resistance,Du...
# 2                                 Lantern Power Ring
# 3  Accelerated Healing,Intelligence,Super Strengt...
# 4  Cold Resistance,Durability,Energy Absorption,S...
#
#                                         Powers_split  Accelerated Healing  \
# 0  [Accelerated Healing, Durability, Longevity, S...                 True
# 1  [Agility, Accelerated Healing, Cold Resistance...                 True
# 2                               [Lantern Power Ring]                False
# 3  [Accelerated Healing, Intelligence, Super Stre...                 True
# 4  [Cold Resistance, Durability, Energy Absorptio...                False
#
#    Durability  Longevity  Super Strength  Stamina  Camouflage  \
# 0        True       True            True     True        True
# 1        True       True            True     True       False
# 2       False      False           False    False       False
# 3       False      False            True     True       False
# 4        True      False            True    False       False
#
#    Self-Sustenance  Agility  Cold Resistance  Underwater breathing  \
# 0             True    False            False                 False
# 1            False     True             True                  True
# 2            False    False            False                 False
# 3            False    False            False                 False
# 4            False    False             True                 False
#
#    Marksmanship  Weapons Master  Intelligence  Telepathy  Immortality  \
# 0         False           False         False      False        False
# 1          True            True          True       True         True
# 2         False           False         False      False        False
# 3         False           False          True      False        False
# 4         False           False         False      False        False
#
#    Reflexes  Enhanced Sight  Sub-Mariner  Lantern Power Ring  Super Speed  \
# 0     False           False        False               False        False
# 1      True            True         True               False        False
# 2     False           False        False                True        False
# 3     False           False        False               False         True
# 4     False           False        False               False        False
#
#    Invulnerability  Animation  Super Breath  Energy Absorption  \
# 0            False      False         False              False
# 1            False      False         False              False
# 2            False      False         False              False
# 3             True       True          True              False
# 4             True      False         False               True
#
#    Elemental Transmogrification  Fire Resistance  Natural Armor  \
# 0                         False            False          False
# 1                         False            False          False
# 2                         False            False          False
# 3                         False            False          False
# 4                          True             True           True
#
#    Molecular Manipulation  Heat Resistance  Matter Absorption  Stealth  \
# 0                   False            False              False    False
# 1                   False            False              False    False
# 2                   False            False              False    False
# 3                   False            False              False    False
# 4                    True             True               True    False
#
#    Flight  Power Suit  Energy Blasts  Energy Beams  Power Cosmic  \
# 0   False       False          False         False         False
# 1   False       False          False         False         False
# 2   False       False          False         False         False
# 3   False       False          False         False         False
# 4   False       False          False         False         False
#
#    Heat Generation  Danger Sense  Teleportation  Phasing  Force Fields  \
# 0            False         False          False    False         False
# 1            False         False          False    False         False
# 2            False         False          False    False         False
# 3            False         False          False    False         False
# 4            False         False          False    False         False
#
#    Hypnokinesis  Energy Manipulation  Invisibility  Enhanced Senses   Jump  \
# 0         False                False         False            False  False
# 1         False                False         False            False  False
# 2         False                False         False            False  False
# 3         False                False         False            False  False
# 4         False                False         False            False  False
#
#    Substance Secretion  Natural Weapons  Wallcrawling  Vision - Thermal  \
# 0                False            False         False             False
# 1                False            False         False             False
# 2                False            False         False             False
# 3                False            False         False             False
# 4                False            False         False             False
#
#    Power Augmentation  Cryokinesis  Duplication  Size Changing  \
# 0               False        False        False          False
# 1               False        False        False          False
# 2               False        False        False          False
# 3               False        False        False          False
# 4               False        False        False          False
#
#    Weapon-based Powers  Shapeshifting  Fire Control  Enhanced Memory  \
# 0                False          False         False            False
# 1                False          False         False            False
# 2                False          False         False            False
# 3                False          False         False            False
# 4                False          False         False            False
#
#    Energy Constructs  Power Absorption  Enhanced Hearing  Time Travel  \
# 0              False             False             False        False
# 1              False             False             False        False
# 2              False             False             False        False
# 3              False             False             False        False
# 4              False             False             False        False
#
#    Enhanced Smell  Water Control  Vision - Telescopic  Magnetism  \
# 0           False          False                False      False
# 1           False          False                False      False
# 2           False          False                False      False
# 3           False          False                False      False
# 4           False          False                False      False
#
#    Vision - Microscopic  Vision - Night  Vision - Heat  Vision - X-Ray  Magic  \
# 0                 False           False          False           False  False
# 1                 False           False          False           False  False
# 2                 False           False          False           False  False
# 3                 False           False          False           False  False
# 4                 False           False          False           False  False
#
#    Psionic Powers  Gliding  Toxin and Disease Resistance  Animal Attributes  \
# 0           False    False                         False              False
# 1           False    False                         False              False
# 2           False    False                         False              False
# 3           False    False                         False              False
# 4           False    False                         False              False
#
#    Animal Oriented Powers  Regeneration  Toxin and Disease Control  Empathy  \
# 0                   False         False                      False    False
# 1                   False         False                      False    False
# 2                   False         False                      False    False
# 3                   False         False                      False    False
# 4                   False         False                      False    False
#
#    Animal Control  Elasticity  Web Creation  Symbiote Costume  Telekinesis  \
# 0           False       False         False             False        False
# 1           False       False         False             False        False
# 2           False       False         False             False        False
# 3           False       False         False             False        False
# 4           False       False         False             False        False
#
#    Levitation  Biokinesis  Sonar  Enhanced Touch  Seismic Power  Energy Armor  \
# 0       False       False  False           False          False         False
# 1       False       False  False           False          False         False
# 2       False       False  False           False          False         False
# 3       False       False  False           False          False         False
# 4       False       False  False           False          False         False
#
#    Radiation Immunity  Density Control  Light Control  Illumination  \
# 0               False            False          False         False
# 1               False            False          False         False
# 2               False            False          False         False
# 3               False            False          False         False
# 4               False            False          False         False
#
#    Molecular Combustion  Dimensional Travel  Audio Control  Sonic Scream  \
# 0                 False               False          False         False
# 1                 False               False          False         False
# 2                 False               False          False         False
# 3                 False               False          False         False
# 4                 False               False          False         False
#
#    Peak Human Condition  Vision - Infrared  Dexterity  Energy Resistance  \
# 0                 False              False      False              False
# 1                 False              False      False              False
# 2                 False              False      False              False
# 3                 False              False      False              False
# 4                 False              False      False              False
#
#    Vision - Cryo  Clairvoyance  Probability Manipulation  Electrokinesis  \
# 0          False         False                     False           False
# 1          False         False                     False           False
# 2          False         False                     False           False
# 3          False         False                     False           False
# 4          False         False                     False           False
#
#    Darkforce Manipulation  Illusions  Death Touch  Gravity Control  \
# 0                   False      False        False            False
# 1                   False      False        False            False
# 2                   False      False        False            False
# 3                   False      False        False            False
# 4                   False      False        False            False
#
#    Precognition  Time Manipulation  Omnilingualism  Astral Projection  \
# 0         False              False           False              False
# 1         False              False           False              False
# 2         False              False           False              False
# 3         False              False           False              False
# 4         False              False           False              False
#
#    Technopath/Cyberpath  Mind Control  Mind Blast  Cloaking  \
# 0                 False         False       False     False
# 1                 False         False       False     False
# 2                 False         False       False     False
# 3                 False         False       False     False
# 4                 False         False       False     False
#
#    Telepathy Resistance  Mind Control Resistance  Radiation Control  \
# 0                 False                    False              False
# 1                 False                    False              False
# 2                 False                    False              False
# 3                 False                    False              False
# 4                 False                    False              False
#
#    Radiation Absorption  Magic Resistance  Dimensional Awareness  \
# 0                 False             False                  False
# 1                 False             False                  False
# 2                 False             False                  False
# 3                 False             False                  False
# 4                 False             False                  False
#
#    Intangibility  Element Control  Wind Control  Echolocation  Radar Sense  \
# 0          False            False         False         False        False
# 1          False            False         False         False        False
# 2          False            False         False         False        False
# 3          False            False         False         False        False
# 4          False            False         False         False        False
#
#    Resurrection  The Force  Possession  Astral Travel  Summoning  Banish  \
# 0         False      False       False          False      False   False
# 1         False      False       False          False      False   False
# 2         False      False       False          False      False   False
# 3         False      False       False          False      False   False
# 4         False      False       False          False      False   False
#
#    Adaptation  Electrical Transport  Speed Force  Omnipotent  Grim Reaping  \
# 0       False                 False        False       False         False
# 1       False                 False        False       False         False
# 2       False                 False        False       False         False
# 3       False                 False        False       False         False
# 4       False                 False        False       False         False
#
#    Reality Warping  Portal Creation  Vitakinesis  Projection  Insanity  \
# 0            False            False        False       False     False
# 1            False            False        False       False     False
# 2            False            False        False       False     False
# 3            False            False        False       False     False
# 4            False            False        False       False     False
#
#    Plant Control  Photographic Reflexes  Anti-Gravity  Power Nullifier  \
# 0          False                  False         False            False
# 1          False                  False         False            False
# 2          False                  False         False            False
# 3          False                  False         False            False
# 4          False                  False         False            False
#
#    Hair Manipulation  Weather Control  Nova Force  Odin Force  Phoenix Force  \
# 0              False            False       False       False          False
# 1              False            False       False       False          False
# 2              False            False       False       False          False
# 3              False            False       False       False          False
# 4              False            False       False       False          False
#
#    Power Sense  Qwardian Power Ring  Melting  Changing Armor  Terrakinesis
# 0        False                False    False           False         False
# 1        False                False    False           False         False
# 2        False                False    False           False         False
# 3        False                False    False           False         False
# 4        False                False    False           False         False

# %%
# dropping unwanted Powers columns
dfmerged = dfmerged.drop(columns=["Powers","Powers_split"])
dfmerged.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher Height(cm) Weight(kg)  \
# 0         A-Bomb      Marvel Comics      203.0      441.0
# 1     Abe Sapien  Dark Horse Comics      191.0       65.0
# 2       Abin Sur          DC Comics      185.0       90.0
# 3    Abomination      Marvel Comics      203.0      441.0
# 4  Absorbing Man      Marvel Comics      193.0      122.0
#
#    Accelerated Healing  Durability  Longevity  Super Strength  Stamina  \
# 0                 True        True       True            True     True
# 1                 True        True       True            True     True
# 2                False       False      False           False    False
# 3                 True       False      False            True     True
# 4                False        True      False            True    False
#
#    Camouflage  Self-Sustenance  Agility  Cold Resistance  \
# 0        True             True    False            False
# 1       False            False     True             True
# 2       False            False    False            False
# 3       False            False    False            False
# 4       False            False    False             True
#
#    Underwater breathing  Marksmanship  Weapons Master  Intelligence  \
# 0                 False         False           False         False
# 1                  True          True            True          True
# 2                 False         False           False         False
# 3                 False         False           False          True
# 4                 False         False           False         False
#
#    Telepathy  Immortality  Reflexes  Enhanced Sight  Sub-Mariner  \
# 0      False        False     False           False        False
# 1       True         True      True            True         True
# 2      False        False     False           False        False
# 3      False        False     False           False        False
# 4      False        False     False           False        False
#
#    Lantern Power Ring  Super Speed  Invulnerability  Animation  Super Breath  \
# 0               False        False            False      False         False
# 1               False        False            False      False         False
# 2                True        False            False      False         False
# 3               False         True             True       True          True
# 4               False        False             True      False         False
#
#    Energy Absorption  Elemental Transmogrification  Fire Resistance  \
# 0              False                         False            False
# 1              False                         False            False
# 2              False                         False            False
# 3              False                         False            False
# 4               True                          True             True
#
#    Natural Armor  Molecular Manipulation  Heat Resistance  Matter Absorption  \
# 0          False                   False            False              False
# 1          False                   False            False              False
# 2          False                   False            False              False
# 3          False                   False            False              False
# 4           True                    True             True               True
#
#    Stealth  Flight  Power Suit  Energy Blasts  Energy Beams  Power Cosmic  \
# 0    False   False       False          False         False         False
# 1    False   False       False          False         False         False
# 2    False   False       False          False         False         False
# 3    False   False       False          False         False         False
# 4    False   False       False          False         False         False
#
#    Heat Generation  Danger Sense  Teleportation  Phasing  Force Fields  \
# 0            False         False          False    False         False
# 1            False         False          False    False         False
# 2            False         False          False    False         False
# 3            False         False          False    False         False
# 4            False         False          False    False         False
#
#    Hypnokinesis  Energy Manipulation  Invisibility  Enhanced Senses   Jump  \
# 0         False                False         False            False  False
# 1         False                False         False            False  False
# 2         False                False         False            False  False
# 3         False                False         False            False  False
# 4         False                False         False            False  False
#
#    Substance Secretion  Natural Weapons  Wallcrawling  Vision - Thermal  \
# 0                False            False         False             False
# 1                False            False         False             False
# 2                False            False         False             False
# 3                False            False         False             False
# 4                False            False         False             False
#
#    Power Augmentation  Cryokinesis  Duplication  Size Changing  \
# 0               False        False        False          False
# 1               False        False        False          False
# 2               False        False        False          False
# 3               False        False        False          False
# 4               False        False        False          False
#
#    Weapon-based Powers  Shapeshifting  Fire Control  Enhanced Memory  \
# 0                False          False         False            False
# 1                False          False         False            False
# 2                False          False         False            False
# 3                False          False         False            False
# 4                False          False         False            False
#
#    Energy Constructs  Power Absorption  Enhanced Hearing  Time Travel  \
# 0              False             False             False        False
# 1              False             False             False        False
# 2              False             False             False        False
# 3              False             False             False        False
# 4              False             False             False        False
#
#    Enhanced Smell  Water Control  Vision - Telescopic  Magnetism  \
# 0           False          False                False      False
# 1           False          False                False      False
# 2           False          False                False      False
# 3           False          False                False      False
# 4           False          False                False      False
#
#    Vision - Microscopic  Vision - Night  Vision - Heat  Vision - X-Ray  Magic  \
# 0                 False           False          False           False  False
# 1                 False           False          False           False  False
# 2                 False           False          False           False  False
# 3                 False           False          False           False  False
# 4                 False           False          False           False  False
#
#    Psionic Powers  Gliding  Toxin and Disease Resistance  Animal Attributes  \
# 0           False    False                         False              False
# 1           False    False                         False              False
# 2           False    False                         False              False
# 3           False    False                         False              False
# 4           False    False                         False              False
#
#    Animal Oriented Powers  Regeneration  Toxin and Disease Control  Empathy  \
# 0                   False         False                      False    False
# 1                   False         False                      False    False
# 2                   False         False                      False    False
# 3                   False         False                      False    False
# 4                   False         False                      False    False
#
#    Animal Control  Elasticity  Web Creation  Symbiote Costume  Telekinesis  \
# 0           False       False         False             False        False
# 1           False       False         False             False        False
# 2           False       False         False             False        False
# 3           False       False         False             False        False
# 4           False       False         False             False        False
#
#    Levitation  Biokinesis  Sonar  Enhanced Touch  Seismic Power  Energy Armor  \
# 0       False       False  False           False          False         False
# 1       False       False  False           False          False         False
# 2       False       False  False           False          False         False
# 3       False       False  False           False          False         False
# 4       False       False  False           False          False         False
#
#    Radiation Immunity  Density Control  Light Control  Illumination  \
# 0               False            False          False         False
# 1               False            False          False         False
# 2               False            False          False         False
# 3               False            False          False         False
# 4               False            False          False         False
#
#    Molecular Combustion  Dimensional Travel  Audio Control  Sonic Scream  \
# 0                 False               False          False         False
# 1                 False               False          False         False
# 2                 False               False          False         False
# 3                 False               False          False         False
# 4                 False               False          False         False
#
#    Peak Human Condition  Vision - Infrared  Dexterity  Energy Resistance  \
# 0                 False              False      False              False
# 1                 False              False      False              False
# 2                 False              False      False              False
# 3                 False              False      False              False
# 4                 False              False      False              False
#
#    Vision - Cryo  Clairvoyance  Probability Manipulation  Electrokinesis  \
# 0          False         False                     False           False
# 1          False         False                     False           False
# 2          False         False                     False           False
# 3          False         False                     False           False
# 4          False         False                     False           False
#
#    Darkforce Manipulation  Illusions  Death Touch  Gravity Control  \
# 0                   False      False        False            False
# 1                   False      False        False            False
# 2                   False      False        False            False
# 3                   False      False        False            False
# 4                   False      False        False            False
#
#    Precognition  Time Manipulation  Omnilingualism  Astral Projection  \
# 0         False              False           False              False
# 1         False              False           False              False
# 2         False              False           False              False
# 3         False              False           False              False
# 4         False              False           False              False
#
#    Technopath/Cyberpath  Mind Control  Mind Blast  Cloaking  \
# 0                 False         False       False     False
# 1                 False         False       False     False
# 2                 False         False       False     False
# 3                 False         False       False     False
# 4                 False         False       False     False
#
#    Telepathy Resistance  Mind Control Resistance  Radiation Control  \
# 0                 False                    False              False
# 1                 False                    False              False
# 2                 False                    False              False
# 3                 False                    False              False
# 4                 False                    False              False
#
#    Radiation Absorption  Magic Resistance  Dimensional Awareness  \
# 0                 False             False                  False
# 1                 False             False                  False
# 2                 False             False                  False
# 3                 False             False                  False
# 4                 False             False                  False
#
#    Intangibility  Element Control  Wind Control  Echolocation  Radar Sense  \
# 0          False            False         False         False        False
# 1          False            False         False         False        False
# 2          False            False         False         False        False
# 3          False            False         False         False        False
# 4          False            False         False         False        False
#
#    Resurrection  The Force  Possession  Astral Travel  Summoning  Banish  \
# 0         False      False       False          False      False   False
# 1         False      False       False          False      False   False
# 2         False      False       False          False      False   False
# 3         False      False       False          False      False   False
# 4         False      False       False          False      False   False
#
#    Adaptation  Electrical Transport  Speed Force  Omnipotent  Grim Reaping  \
# 0       False                 False        False       False         False
# 1       False                 False        False       False         False
# 2       False                 False        False       False         False
# 3       False                 False        False       False         False
# 4       False                 False        False       False         False
#
#    Reality Warping  Portal Creation  Vitakinesis  Projection  Insanity  \
# 0            False            False        False       False     False
# 1            False            False        False       False     False
# 2            False            False        False       False     False
# 3            False            False        False       False     False
# 4            False            False        False       False     False
#
#    Plant Control  Photographic Reflexes  Anti-Gravity  Power Nullifier  \
# 0          False                  False         False            False
# 1          False                  False         False            False
# 2          False                  False         False            False
# 3          False                  False         False            False
# 4          False                  False         False            False
#
#    Hair Manipulation  Weather Control  Nova Force  Odin Force  Phoenix Force  \
# 0              False            False       False       False          False
# 1              False            False       False       False          False
# 2              False            False       False       False          False
# 3              False            False       False       False          False
# 4              False            False       False       False          False
#
#    Power Sense  Qwardian Power Ring  Melting  Changing Armor  Terrakinesis
# 0        False                False    False           False         False
# 1        False                False    False           False         False
# 2        False                False    False           False         False
# 3        False                False    False           False         False
# 4        False                False    False           False         False

# %% [markdown]
# Compare the average weight of super powers who have Super Speed to those who do not.

# %%
dfmerged["Weight(kg)"] = dfmerged["Weight(kg)"].astype(float)
tempdf1 = dfmerged.groupby(["Super Speed"]).mean(numeric_only = True)
tempdf1[["Weight(kg)"]]
# Out:
#              Weight(kg)
# Super Speed
# False        101.773585
# True         129.404040

# %% [markdown]
# The average weight for superheroes that do have Super Speed as a power have a higher average weight.

# %% [markdown]
# What is the average height of heroes for each publisher?

# %%
dfmerged["Height(cm)"] = dfmerged["Height(cm)"].astype(float)
tempdf2 = dfmerged.groupby(["Publisher"]).mean(numeric_only = True)
tempdf2[["Height(cm)"]]
# Out:
#                    Height(cm)
# Publisher
# DC Comics          181.923913
# Dark Horse Comics  176.909091
# George Lucas       159.600000
# Image Comics       211.000000
# Marvel Comics      191.546128
# Shueisha           171.500000
# Star Trek          181.500000
# Team Epic TV       180.750000
# Unknown            178.000000

# %% [markdown]
# The Publisher which has the highest average Height for superheroes is Image Comics.
